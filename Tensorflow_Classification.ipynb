# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf

import pandas as pd

# %%
CSV_COLUMN_NAMES = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Species']
SPECIES = ['Setosa', 'Versicolor', 'Virginica']
# Lets define some constants to help us later on

# %%
train_path = tf.keras.utils.get_file(
    "iris_training.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_training.csv")
test_path = tf.keras.utils.get_file(
    "iris_test.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_test.csv")

train = pd.read_csv(train_path, names=CSV_COLUMN_NAMES, header=0)
test = pd.read_csv(test_path, names=CSV_COLUMN_NAMES, header=0)
# Here we use keras (a module inside of TensorFlow) to grab our datasets and read them into a pandas dataframe

# %%
test.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth  Species
# 0          5.9         3.0          4.2         1.5        1
# 1          6.9         3.1          5.4         2.1        2
# 2          5.1         3.3          1.7         0.5        0
# 3          6.0         3.4          4.5         1.6        1
# 4          5.5         2.5          4.0         1.3        1

# %%
train_y = train.pop('Species')
test_y = test.pop('Species')
train.head() # the species column is now gone
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth
# 0          6.4         2.8          5.6         2.2
# 1          5.0         2.3          3.3         1.0
# 2          4.9         2.5          4.5         1.7
# 3          4.9         3.1          1.5         0.1
# 4          5.7         3.8          1.7         0.3

# %%
train_y.head()
# Out:
# 0    2
# 1    1
# 2    2
# 3    0
# 4    0
# Name: Species, dtype: int64

# %%
train.shape  # we have 120 entires with 4 features
# Out:
# (120, 4)

# %%
def input_fn(features, labels, training=True, batch_size=256):
    # Convert the inputs to a Dataset.
    dataset = tf.data.Dataset.from_tensor_slices((dict(features), labels))

    # Shuffle and repeat if you are in training mode.
    if training:
        dataset = dataset.shuffle(1000).repeat()
    
    return dataset.batch(batch_size)

# %%
# Feature columns describe how to use the input.
my_feature_columns = []
for key in train.keys():
    my_feature_columns.append(tf.feature_column.numeric_column(key=key))
print(my_feature_columns)
# Out:
# [NumericColumn(key='SepalLength', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='SepalWidth', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='PetalLength', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='PetalWidth', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %%
# Build a DNN with 2 hidden layers with 30 and 10 hidden nodes each.
classifier = tf.estimator.DNNClassifier(
    feature_columns=my_feature_columns,
    # Two hidden layers of 30 and 10 nodes respectively.
    hidden_units=[30, 10],
    # The model must choose between 3 classes.
    n_classes=3)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\PMYLS\AppData\Local\Temp\tmpe8ax1gvs
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\PMYLS\\AppData\\Local\\Temp\\tmpe8ax1gvs', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
classifier.train(
    input_fn=lambda: input_fn(train, train_y, training=True),
    steps=15000)
# We include a lambda to avoid creating an inner function previously
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\PMYLS\AppData\Local\Temp\tmpe8ax1gvs\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 1.1263149, step = 0
# INFO:tensorflow:global_step/sec: 518.872
# INFO:tensorflow:loss = 0.9394187, step = 100 (0.200 sec)
# INFO:tensorflow:global_step/sec: 711.381
# INFO:tensorflow:loss = 0.8699784, step = 200 (0.133 sec)
# INFO:tensorflow:global_step/sec: 751.499
# INFO:tensorflow:loss = 0.82793546, step = 300 (0.133 sec)
# INFO:tensorflow:global_step/sec: 612.307
# INFO:tensorflow:loss = 0.79078263, step = 400 (0.166 sec)
# INFO:tensorflow:global_step/sec: 670.041
# INFO:tensorflow:loss = 0.7569143, step = 500 (0.147 sec)
# INFO:tensorflow:global_step/sec: 898.698
# INFO:tensorflow:loss = 0.7356735, step = 600 (0.111 sec)
# INFO:tensorflow:global_step/sec: 917.512
# INFO:tensorflow:loss = 0.7092955, step = 700 (0.109 sec)
# INFO:tensorflow:global_step/sec: 1001.06
# INFO:tensorflow:loss = 0.6922452, step = 800 (0.100 sec)
# INFO:tensorflow:global_step/sec: 853.313
# INFO:tensorflow:loss = 0.6695231, step = 900 (0.117 sec)
# INFO:tensorflow:global_step/sec: 862.504
# INFO:tensorflow:loss = 0.65671325, step = 1000 (0.116 sec)
# INFO:tensorflow:global_step/sec: 856.921
# INFO:tensorflow:loss = 0.62869865, step = 1100 (0.117 sec)
# INFO:tensorflow:global_step/sec:
 (0.117 sec)
# INFO:tensorflow:global_step/sec: 851.779
# INFO:tensorflow:loss = 0.15171166, step = 13700 (0.120 sec)
# INFO:tensorflow:global_step/sec: 929.043
# INFO:tensorflow:loss = 0.1398257, step = 13800 (0.105 sec)
# INFO:tensorflow:global_step/sec: 925.776
# INFO:tensorflow:loss = 0.15170172, step = 13900 (0.120 sec)
# INFO:tensorflow:global_step/sec: 798
# INFO:tensorflow:loss = 0.1272731, step = 14000 (0.113 sec)
# INFO:tensorflow:global_step/sec: 926.943
# INFO:tensorflow:loss = 0.14072634, step = 14100 (0.108 sec)
# INFO:tensorflow:global_step/sec: 923.059
# INFO:tensorflow:loss = 0.14175963, step = 14200 (0.108 sec)
# INFO:tensorflow:global_step/sec: 842.665
# INFO:tensorflow:loss = 0.12515858, step = 14300 (0.119 sec)
# INFO:tensorflow:global_step/sec: 840.842
# INFO:tensorflow:loss = 0.15092455, step = 14400 (0.121 sec)
# INFO:tensorflow:global_step/sec: 964.492
# INFO:tensorflow:loss = 0.13332899, step = 14500 (0.102 sec)
# INFO:tensorflow:global_step/sec: 857.182
# INFO:tensorflow:loss = 0.1358172, step = 14600 (0.117 sec)
# INFO:tensorflow:global_step/sec: 1001.96
# INFO:tensorflow:loss = 0.13363026, step = 14700 (0.100 sec)
# INFO:tensorflow:global_step/sec: 901.291
# INFO:tensorflow:loss = 0.12748641, step = 14800 (0.133 sec)
# INFO:tensorflow:global_step/sec: 819.98
# INFO:tensorflow:loss = 0.1364311, step = 14900 (0.100 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 15000...
# INFO:tensorflow:Saving checkpoints for 15000 into C:\Users\PMYLS\AppData\Local\Temp\tmpe8ax1gvs\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 15000...
# INFO:tensorflow:Loss for final step: 0.1320289.

# %%
eval_result = classifier.evaluate(
    input_fn=lambda: input_fn(test, test_y, training=False))

print('\nTest set accuracy: {accuracy:0.3f}\n'.format(**eval_result))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2024-02-28T15:41:52
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\PMYLS\AppData\Local\Temp\tmpe8ax1gvs\model.ckpt-15000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.25601s
# INFO:tensorflow:Finished evaluation at 2024-02-28-15:41:53
# INFO:tensorflow:Saving dict for global step 15000: accuracy = 0.96666664, average_loss = 0.13868241, global_step = 15000, loss = 0.13868241
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 15000: C:\Users\PMYLS\AppData\Local\Temp\tmpe8ax1gvs\model.ckpt-15000
#
# Test set accuracy: 0.967

# %%
def input_fn(features, batch_size=256):
    # Convert the inputs to a Dataset without labels.
    return tf.data.Dataset.from_tensor_slices(dict(features)).batch(batch_size)

features = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth']
predict = {}

print("Please type numeric values as prompted.")
for feature in features:
  valid = True
  while valid: 
    val = input(feature + ": ")
    if not val.isdigit(): valid = False

  predict[feature] = [float(val)]

predictions = classifier.predict(input_fn=lambda: input_fn(predict))
for pred_dict in predictions:
    print(pred_dict)
    class_id = pred_dict['class_ids'][0]
    probability = pred_dict['probabilities'][class_id]

    print('Prediction is "{}" ({:.1f}%)'.format(
        SPECIES[class_id], 100 * probability))
# Out:
# Please type numeric values as prompted.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\PMYLS\AppData\Local\Temp\tmpe8ax1gvs\model.ckpt-15000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# {'logits': array([-1.7456563, -4.6573973, -7.032988 ], dtype=float32), 'probabilities': array([0.94389826, 0.0513301 , 0.00477162], dtype=float32), 'class_ids': array([0], dtype=int64), 'classes': array([b'0'], dtype=object), 'all_class_ids': array([0, 1, 2]), 'all_classes': array([b'0', b'1', b'2'], dtype=object)}
# Prediction is "Setosa" (94.4%)

# %%
# Here is some example input and expected classes you can try above
expected = ['Setosa', 'Versicolor', 'Virginica']
predict_x = {
    'SepalLength': [5.1, 5.9, 6.9],
    'SepalWidth': [3.3, 3.0, 3.1],
    'PetalLength': [1.7, 4.2, 5.4],
    'PetalWidth': [0.5, 1.5, 2.1],
}
